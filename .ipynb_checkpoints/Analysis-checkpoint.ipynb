# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np

# %%
df = pd.read_pickle('test.pkl')

# %%
# Filtering
df = df[df['affiliation'].isin(['Fidesz/KDNP' ,'United for Hungary', 'Our Country'])]

# %%
#df.describe().transpose()
#df.info()
#df.isna().sum()
#fil = df[df['votes'] != 0]

#fil = fil[fil['votes']> 5000]
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(data=df, x = 'votes', hue ='affiliation', kde=True, alpha = 0.5, bins =20)
#fil.votes.hist(bins=20)
fil.log = fil.votes.apply(lambda x: np.log(x))
#fil.log.hist(bins=70)

# %% [markdown]
# # Constituency analysis

# %%
dist = df.groupby('district').sum().drop(columns = 'relative')
dist.votes.hist(bins = 10)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Party analysis

# %%
party = df.groupby('affiliation').sum().drop(columns = 'relative')
party['%'] = party['votes'].apply(lambda x : (x/party['votes'].sum())*100)
party = party.sort_values(by='%', ascending = False)
party['%'].plot(kind='bar')
party
# Out:
#                       votes          %
# affiliation
# Fidesz/KDNP         2823419  52.522003
# United for Hungary  1983708  36.901472
# Our Country          307064   5.712087
# MKKP                 126648   2.355940
# MEMO                  64341   1.196889
# Others                39013   0.725730
# Normal party          31495   0.585878

# %%
fidesz = {'mail' : 251468, 'name' : 'Fidesz', 'total' : 3060706, 'constituency' : 2823419}
united_for_hungary = {'mail' : 11034, 'name' : 'United for Hungary','total' : 1947331, 'constituency' : 1983708}
Our_country = {'mail' : 2836, 'name' :'Our Homeland', 'total' : 332487, 'constituency' : 307064}

parties = pd.DataFrame([fidesz, united_for_hungary, Our_country])
parties['diff'] = parties['total'] - parties['constituency']
parties.index = parties['name']
parties

# %% [markdown]
# Aggregation of list votes
# Total number of valid votes cast for party lists
# 5,624,225 ( 99.46% )
# Total number of valid votes cast on nationality lists
# 30,635 ( 0.54% )
# Total number of valid votes cast for lists
# 5,654,860 ( 100.00% )

# %% [markdown]
# # Benford analysis

# %%
import seaborn as sns
#df = df[df['votes'] != 0]
df = fil
df['test'] = df.votes.apply(lambda x : int(str(x)[0]))
df['benford2'] = df.votes.apply(lambda x : int(str(x)[1]))
#df = df[df['test'] != 0]
#df['test'].value_counts().plot(kind ='bar')
sns.countplot(data=df, x = 'benford2', color = 'b')
fil
# Out:
#                 name  votes  relative  \
# 0       CSÁRDI ANTAL  21778     48.47
# 1      BÖRÖCZ LÁSZLÓ  19144     42.60
# 2         HOTZ ANTAL   1975      4.40
# 3     SZIKORA ISTVÁN   1229      2.74
# 4    MURÁNYI GERGELY    543      1.21
# ..               ...    ...       ...
# 771     HOKKER TIBOR   2711      5.50
# 772       NAGY DÁVID    975      1.98
# 773     BORDA BALÁZS    504      1.02
# 774      BARNA TAMÁS    410      0.83
# 775   SZÉKELY SÁNDOR    122      0.25
#
#                                               district         affiliation  \
# 0    ORSZÁGGYŰLÉSI KÉPVISELŐK VÁLASZTÁSABUDAPEST, 0...  United for Hungary
# 1    ORSZÁGGYŰLÉSI KÉPVISELŐK VÁLASZTÁSABUDAPEST, 0...         Fidesz/KDNP
# 2    ORSZÁGGYŰLÉSI KÉPVISELŐK VÁLASZTÁSABUDAPEST, 0...                MKKP
# 3    ORSZÁGGYŰLÉSI KÉPVISELŐK VÁLASZTÁSABUDAPEST, 0...         Our Country
# 4    ORSZÁGGYŰLÉSI KÉPVISELŐK VÁLASZTÁSABUDAPEST, 0...                MEMO
# ..                                                 ...                 ...
# 771  ORSZÁGGYŰLÉSI KÉPVISELŐK VÁLASZTÁSAZALA, 03. s...         Our Country
# 772  ORSZÁGGYŰLÉSI KÉPVISELŐK VÁLASZTÁSAZALA, 03. s...                MKKP
# 773  ORSZÁGGYŰLÉSI KÉPVISELŐK VÁLASZTÁSAZALA, 03. s...        Normal party
# 774  ORSZÁGGYŰLÉSI KÉPVISELŐK VÁLASZTÁSAZALA, 03. s...                MEMO
# 775  ORSZÁGGYŰLÉSI KÉPVISELŐK VÁLASZTÁSAZALA, 03. s...              Others
#
#      test  benford2
# 0       2         1
# 1       1         9
# 2       1         9
# 3       1         2
# 4       5         4
# ..    ...       ...
# 771     2         7
# 772     9         7
# 773     5         0
# 774     4         1
# 775     1         2
#
# [663 rows x 7 columns]

# %%
# create Benford test dataframe

ben = fil.groupby('test').count()

ben['Benford distribution'] = [0, 30.1, 17.6, 12.5, 9.7, 7.9, 6.7, 5.8, 5.1, 4.6]
ben['Benford distribution2'] = [12.00,11.40,10.90,10.40, 10.00, 9.70, 9.30, 9.00, 8.80, 8.50]

ben = ben.drop(columns = ['name', 'relative', 'district'])
ben['Hungarian election'] = ben['votes']/sum(ben['votes'])*100
ben['test'] = ben.index

#perform Chi-Square Goodness of Fit Test
stats.chisquare(f_obs=ben['Hungarian election'].array, f_exp=ben['Benford distribution2'].array)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19296/104545493.py in <module>
#       3 ben = fil.groupby('test').count()
#       4
# ----> 5 ben['Benford distribution'] = [0, 30.1, 17.6, 12.5, 9.7, 7.9, 6.7, 5.8, 5.1, 4.6]
#       6 ben['Benford distribution2'] = [12.00,11.40,10.90,10.40, 10.00, 9.70, 9.30, 9.00, 8.80, 8.50]
#       7
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (10) does not match length of index (9)

# %%
colors = ['b']
fig, ax = plt.subplots(figsize=(10,6))
#sns.set_theme(style="whitegrid", context="talk")
sns.barplot(data=ben, y = 'Benford distribution', x ='test', saturation =1, palette=sns.color_palette(colors) )
#ben['Benford distribution'].plot(kind='bar', alpha = 0.9)
#(ben['Hungarian election']).plot(kind='bar', color = 'r', alpha = 0.3)
plt.xlabel('First digit')
plt.ylabel('Occurence [%]')
plt.tight_layout()
plt.savefig('Benfords Distribution')

# %%
colors = ["b", "#FF6A00"]

fig, ax = plt.subplots(figsize=(10,6))
sns.set_theme(style="whitegrid", context="talk")
lol = pd.melt(ben, id_vars=['test'], value_vars=['Benford distribution', 'Hungarian election' ])
lol.rename(columns={'variable' : ' '}, inplace =True)
sns.barplot(data=lol, y = 'value', x='test', hue =' ', alpha = 0.9, palette=sns.color_palette(colors), saturation =1 )
plt.xlabel('First digit')
plt.ylabel('Occurence [%]')

# Set your custom color palette
plt.legend(bbox_to_anchor=(.98, 0.98), loc=1, borderaxespad=0. , fontsize =10)
plt.legend(fontsize = 15)
plt.tight_layout()
plt.savefig('Hungarian electon')

# %%
lol

# %%
lol.columns

# %%
fig2, ax = plt.subplots(figsize=(10,6))
sns.lineplot(data=lol, y = 'value', x='test', hue =' ', marker ='o', legend = False)
plt.xlabel('First digit')
plt.ylabel('Occurence [%]')
font = {'weight' : 'normal',
        'size'   : 22}

plt.rc('font', **font)
#plt.legend(bbox_to_anchor=(0.98, 0.98), loc=0, borderaxespad=0. , fontsize =10)
plt.tight_layout()

# %%
ben['Hungarian election'].plot()
ben['Benford distribution'].plot(kind = 'bar')

# %%
ben

# %% [markdown]
# # Log test

# %%
import numpy as np
df['log'] = df['votes'].apply(lambda x: np.log(x))

# %%
df['log'].hist(bins = 30)

# %%
lal = df[df['votes']  > 100]

lal['votes'].dropna().hist()
